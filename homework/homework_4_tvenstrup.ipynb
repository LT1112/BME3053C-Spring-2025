# %% [markdown]
# <a href="https://colab.research.google.com/github/LT1112/BME3053C-Spring-2025/blob/main/homework/homework_4_tvenstrup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# \\# BME3053C - Homework 4
#
# <br/>
#
# <h1 align="center">Homework 4</h1>
#
# ---
#
# <center><h2>Liam Tvenstrup</h2></center>
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uf-bme/BME3053C-Spring-2025/blob/main/lessons/02_Python_Basics.ipynb)

# %% [markdown]
# Solution to Task 1:

# %%
import pandas as pd

anscombe_df = pd.read_json('/content/sample_data/anscombe.json')

grouped_df = anscombe_df.groupby('Series')
grouped_df.describe()
# Out:
#            X                                               Y            \
#        count mean       std  min  25%  50%   75%   max count      mean
# Series
# I       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# II      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III     11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV      11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#              std   min    25%   50%   75%    max
# Series
# I       2.032890  4.26  6.315  7.58  8.57  10.84
# II      2.031657  3.10  6.695  8.14  8.95   9.26
# III     2.030424  5.39  6.250  7.11  7.98  12.74
# IV      2.030579  5.25  6.170  7.04  8.19  12.50

# %%
anscombe_df.boxplot(column=['X', 'Y'], by='Series', grid=True, fontsize=12, layout=(1, 2))
# Out:
# array([<Axes: title={'center': 'X'}, xlabel='Series'>,
#        <Axes: title={'center': 'Y'}, xlabel='Series'>], dtype=object)

# %%
grouped_df.plot(kind="scatter", x="X", y="Y", subplots=True, layout=(2, 2), sharex=True, sharey=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/core.py:896: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="best")
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/core.py:896: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="best")
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/core.py:896: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="best")
# ...

# %% [markdown]
# The four datasets contain point coordinates in the cartesian plane. By viewing a statistical summary, a box plot, and a scatter plot analysis of these datasets, I was able to see how they are related. First, all four datasets contained the same number of data points (11 sets of x,y each). All 4 datasets had x value sets with the same mean and standard deviation. However, the y value sets for these datasets were not as uniform. The means of these y value sets were almost identical, but not completely. The standard deviations were in close proximity to each other, but they varied after the thousandths place (which is a fairly insignificant difference). The box plot analysis helped me see that all datasets had a similar distribution (there was no significant difference between any of the datasets in terms of both x and y). The y value sets for datasets III and IV each contained an outlier and the x value set for dataset IV also contained an outlier. This set, however, had no spread, as all x values in dataset IV (with the exception of the outlier) were identical (x=8). In general, the x values were slightly higher (via the medians in the box plots) than the y values. According to the scatter plots, dataset I contained points that may fit a trendline, but are fairly spread out and not easily identified as a linear trend. If it did have a trendline, it would have a positive slope from close to the y-intercept of y=4. Dataset II contained points from a parabolic function with a negative slope and more concentrated points near the vertex. The points fit this function completely, without any error. Dataset III contains points from a linear function with a slope of around 2/5. However, there is one outlier point in this dataset that deviates from this function heavily (at x=12.5). Dataset IV contains points that share the same x value, which would graph a vertical line. These points are concentrated near each other, with the exception of one point that does not fit this vertical line, and is far from the rest of the points in the dataset. This is similar to dataset III, except the x and y values are both an outlier, whereas in dataset III, only the y value was an outlier.
